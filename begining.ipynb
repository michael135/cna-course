# %%
import networkx as nx
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# !which python
# Out:
# /Users/mdymshits/virtualenv/graph/bin/python

# %%
# %cd ~/cna-course/CNA-data/Korea/
# %ls
# Out:
# /Users/mdymshits/cna-course/CNA-data/Korea
# Korea.paj            Korea1_members.clu   Korea2_members.clu
# Korea1.net           Korea2.net
# Korea1_adopters.clu  Korea2_adopters.clu

# %%
k = nx.read_pajek('Korea1.net')

# %%
nx.draw(k)

# %%
nx.draw_networkx(k)

# %%
nx.draw_spectral(k)

# %%
nx.draw_spring(k)

# %%
# %cd ~/cna-course/CNA-data/Tina/
# %ls
# Out:
# /Users/mdymshits/cna-course/CNA-data/tina
# AnsCalT.net   AskCal.net    DisCal.net    DisCog.net
# AnsCogT.net   AskCog.net    DisCalSn.net  Tina.paj

# %%
k = nx.read_pajek('AnsCalT.net')
nx.draw(k)

# %%
nx.draw_networkx(k)
